# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Datasets/Jobs_data/combined_jobs.csv')

# %%
df.head()
# Out:
#                                            job_title         city  \
# 0   Global Mobility Intern, AI/ML 5G Advanced Modem     San Diego
# 1  Software Intern, 5G RAN and AI Kubernetes orch...  Santa Clara
# 2  Software Intern, 5G and 6G RAN AI with digital...  Santa Clara
# 3                   Intern, AI/ML 5G Advanced Modem     San Diego
# 4  Staff Software / Firmware Engineer - 5G, AI/ML...  Santa Clara
#
#          country          company_name  is_remote        date
# 0  United States  samsungsemiconductor      False  2024-03-16
# 1  United States                Nvidia      False  2023-12-02
# 2  United States                Nvidia      False  2023-11-22
# 3  United States  samsungsemiconductor      False  2023-11-14
# 4  United States               marvell      False  2023-09-21

# %%
df.isnull().sum()
# Out:
# job_title         0
# city            103
# country         103
# company_name      1
# is_remote         0
# date              0
# dtype: int64

# %%
df.sample(10)
# Out:
#                                                job_title           city  \
# 4865                                   Sr. Data Engineer         Lenexa
# 10267                     Senior Data Science Consultant      Rotterdam
# 10039                               Senior Data Engineer      Hyderabad
# 4588                                 Junior Data Analyst         Lisboa
# 10207         Data Science Senior Analyst - AVP (Hybrid)         Irving
# 8369                           Lead Data Science Analyst  not_available
# 7474            Vice President, Lead Data Engineer - ATL        Atlanta
# 9656   Senior Software Engineer, Deep Learning Inference    Santa Clara
# 2984                    Senior Quantitative Risk Analyst        Toronto
# 12413                               Sr. QA Data Engineer        Raleigh
#
#              country                 company_name  is_remote        date
# 4865   United States                         cacu      False  2024-08-30
# ...

# %%
filtered_df = df[df['job_title'].str.contains('Sr.')]

# %%
filtered_df
# Out:
#                                                job_title           city  \
# 214                     Sr Manager, Actuary (DaVita IKC)  not_available
# 284                     Sr Analyst, Actuary (DaVita IKC)  not_available
# 325                                Sr. Assistant Actuary  not_available
# 347    Actuary (Open to hiring at Actuary II or Sr. A...     Des Moines
# 489    Actuary (Open to hiring at Actuary II or Sr. A...     Des Moines
# ...                                                  ...            ...
# 12533                                    Sr Data Analyst        Rosario
# 12534                 [Job 14419 - CoH] Sr Data Engineer  not_available
# 12535                 [Job 14419 - CoH] Sr Data Engineer  not_available
# 12536  Portfolio Data Analyst Sr. Advisor - Evernorth...     Bloomfield
# 12538                       Sr Machine Learning Engineer         Madrid
#
#              country company_name  is_remote        date
# ...

# %%
df.nunique()
# Out:
# job_title       3794
# city             712
# country           79
# company_name    1245
# is_remote          2
# date             604
# dtype: int64
