# %%
import pandas as pd
import numpy as np

df = pd.read_csv('laptop_data.csv')

# %%
df.head()
# Out:
#                                                Title Product Price  \
# 0  ASUS TUF GAMING A15 FA507RM 15.6 INCH FHD 144H...      181,900৳
# 1  ASUS ROG STRIX G15 G513RM 15.6 INCH FULL HD 30...      218,000৳
# 2  ASUS TUF GAMING A15 FA507RE 15.6 INCH FHD 300H...      153,900৳
# 3  ASUS TUF A15 FA506QM 15.6 INCH FHD 144HZ DISPL...      176,000৳
# 4  ASUS ROG ZEPHYRUS G15 GA503RM 15.6 INCH WQHD 2...      265,000৳
#
#    Stock Status                  Product Model Warranty Processor Memory  \
# 0           NaN         TUF GAMING A15 FA507RM  2 Years       NaN    NaN
# 1           NaN           ROG Strix G15 G513RM  2 Years       NaN    NaN
# 2           NaN         TUF GAMING A15 FA507RE  2 Years       NaN    NaN
# 3           NaN         TUF GAMING A15 FA506QM  2 Years       NaN    NaN
# 4           NaN  ASUS ROG ZEPHYRUS G15 GA503RM  2 Years       NaN    NaN
#
#                                              Storage  Display Graphics  \
# ...

# %%
df.isnull().sum()
# Out:
# Title                0
# Product Price        0
# Special Price       20
# Stock Status        20
# Product Model        0
# Warranty             0
# Processor           15
# Memory              15
# Storage              1
# Display              0
# Graphics            15
# WebCam               1
# Keyboard             0
# Networking           0
# Operating System    20
# Adapter              1
# Battery             15
# Color                1
# Body Material       20
# Weight               0
# dtype: int64
