# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Reindexing

# %% [markdown]
#  An important method on pandas objects is reindex, which means to create a new
#  object with the values rearranged to align with the new index.

# %%
obj = pd.Series([1, 2, 3, 4], index = ['d', 'b', 'a', 'c'])

# %%
obj
# Out:
# d    1
# b    2
# a    3
# c    4
# dtype: int64

# %%
obj2 = obj.reindex(['a', 'b', 'c', 'd', 'e'])
obj2
# Out:
# a    3.0
# b    2.0
# c    4.0
# d    1.0
# e    NaN
# dtype: float64

# %%
obj3 = pd.Series(["blue", "purple", "yellow"], index=[0, 2, 4])
obj3
# Out:
# 0      blue
# 2    purple
# 4    yellow
# dtype: object

# %%
obj3.reindex(np.arange(6))
# Out:
# 0      blue
# 1       NaN
# 2    purple
# 3       NaN
# 4    yellow
# 5       NaN
# dtype: object

# %%
obj3.reindex(np.arange(6), method = 'ffill') # which forward-fills the values:
# Out:
# 0      blue
# 1      blue
# 2    purple
# 3    purple
# 4    yellow
# 5    yellow
# dtype: object

# %%
frame = pd.DataFrame(np.arange(9).reshape((3, 3)),
                    index=['a', 'b', 'c'],
                    columns=['Ohio', 'Texas', 'California'])
frame
# Out:
#    Ohio  Texas  California
# a     0      1           2
# b     3      4           5
# c     6      7           8

# %%
frame2 = frame.reindex(index=['a', 'b', 'c', 'd'])
frame2
# Out:
#    Ohio  Texas  California
# a   0.0    1.0         2.0
# b   3.0    4.0         5.0
# c   6.0    7.0         8.0
# d   NaN    NaN         NaN

# %%
frame2 = frame.reindex(index=['a', 'b', 'c', 'd'], method = 'ffill')
frame2
# Out:
#    Ohio  Texas  California
# a     0      1           2
# b     3      4           5
# c     6      7           8
# d     6      7           8

# %% [markdown]
#  The columns can be reindexed with the columns keyword:

# %%
states = ["Texas", "Utah", "California"]
frame.reindex(columns=states)
# Out:
#    Texas  Utah  California
# a      1   NaN           2
# b      4   NaN           5
# c      7   NaN           8

# %% [markdown]
# Another way to reindex a particular axis is to pass the new axis labels as a positional
#  argument and then specify the axis to reindex with the axis keyword:

# %%
frame.reindex(states, axis = 'columns')
# Out:
#    Texas  Utah  California
# a      1   NaN           2
# b      4   NaN           5
# c      7   NaN           8

# %% [markdown]
# ![reindexing](Assets/reindex_methods.png)

# %% [markdown]
#  We can also reindex by using the loc operator

# %%
frame
# Out:
#    Ohio  Texas  California
# a     0      1           2
# b     3      4           5
# c     6      7           8

# %%
frame.loc[['a', 'b', 'c'], ['California', 'Ohio']]
# Out:
#    California  Ohio
# a           2     0
# b           5     3
# c           8     6

# %% [markdown]
# ## Dropping Entries from an Axis

# %%
obj = pd.Series(np.arange(5.), index=["a", "b", "c", "d", "e"])

# %%
obj
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# e    4.0
# dtype: float64

# %%
obj['c'] = 3

# %%
obj
# Out:
# a    0.0
# b    1.0
# d    3.0
# e    4.0
# c    3.0
# dtype: float64

# %%
obj.drop('c')
# Out:
# a    0.0
# b    1.0
# d    3.0
# e    4.0
# dtype: float64

# %%
obj.drop(['d', 'e'])
# Out:
# a    0.0
# b    1.0
# c    3.0
# dtype: float64

# %% [markdown]
# With DataFrame, index values can be deleted from either axis. To illustrate this, we
#  first create an example DataFrame:

# %%
data = pd.DataFrame(np.arange(16).reshape((4, 4)),                    
                    index=["Ohio", "Colorado", "Utah", "New York"],
                     columns=["one", "two", "three", "four"])

# %%
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
data.drop(index = ['Colorado', 'Ohio'])
# Out:
#           one  two  three  four
# Utah        8    9     10    11
# New York   12   13     14    15

# %% [markdown]
# To drop labels from the columns, instead use the columns keyword

# %%
data.drop(columns=['two'])
# Out:
#           one  three  four
# Ohio        0      2     3
# Colorado    4      6     7
# Utah        8     10    11
# New York   12     14    15

# %%
data.drop('two', axis=1)
# Out:
#           one  three  four
# Ohio        0      2     3
# Colorado    4      6     7
# Utah        8     10    11
# New York   12     14    15

# %%
data.drop('Utah', axis=0)
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# New York   12   13     14    15

# %%
data.drop(['two', 'three'], axis = 'columns')
# Out:
#           one  four
# Ohio        0     3
# Colorado    4     7
# Utah        8    11
# New York   12    15

# %% [markdown]
# ## Indexing, Selection, and Filtering

# %%
obj = pd.Series(np.arange(4.), index=["a", "b", "c", "d"])

# %%
obj
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# dtype: float64

# %%
obj['a']
# Out:
# 0.0

# %%
obj[2:]
# Out:
# c    2.0
# d    3.0
# dtype: float64

# %%
obj[1:3]
# Out:
# b    1.0
# c    2.0
# dtype: float64

# %%
obj[['b', 'c']]
# Out:
# b    1.0
# c    2.0
# dtype: float64

# %%
obj[[1, 3]]
# Out:
# C:\Users\ahamm\AppData\Local\Temp\ipykernel_14864\2982346117.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   obj[[1, 3]]
# b    1.0
# d    3.0
# dtype: float64

# %%
obj.iloc[[1, 3]]
# Out:
# b    1.0
# d    3.0
# dtype: float64

# %%
obj[obj<2]
# Out:
# a    0.0
# b    1.0
# dtype: float64

# %% [markdown]
#  the preferred way to select index values is
#  with the special loc operator:

# %%
obj.loc[['d', 'a']]
# Out:
# d    3.0
# a    0.0
# dtype: float64

# %%
obj1 = pd.Series([1, 2, 3], index=[2, 0, 1])
obj2 = pd.Series([1, 2, 3], index=["a", "b", "c"])
print(obj1)
print(obj2)
# Out:
# 2    1
# 0    2
# 1    3
# dtype: int64
# a    1
# b    2
# c    3
# dtype: int64

# %%
obj1.iloc[[0, 1, 2]]
# Out:
# 2    1
# 0    2
# 1    3
# dtype: int64

# %%
obj2.iloc[[0, 1, 2]]
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
obj2.loc['b':]
# Out:
# b    2
# c    3
# dtype: int64

# %%
data = pd.DataFrame(np.arange(16).reshape((4, 4)),                   
index=["Ohio", "Colorado", "Utah", "New York"],
 columns=["one", "two", "three", "four"])

# %%
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
data['two']
# Out:
# Ohio         1
# Colorado     5
# Utah         9
# New York    13
# Name: two, dtype: int32

# %%
data[['three', 'one']]
# Out:
#           three  one
# Ohio          2    0
# Colorado      6    4
# Utah         10    8
# New York     14   12

# %%
data[:2]
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7

# %% [markdown]
# Another use case is indexing with a Boolean DataFrame, such as one produced by
#  a scalar comparison.

# %%
data[data['three'] > 5]
# Out:
#           one  two  three  four
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
data[data<5] = 0

# %%
data
# Out:
#           one  two  three  four
# Ohio        0    0      0     0
# Colorado    0    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %% [markdown]
# Selection on DataFrame with loc and iloc

# %%
data
# Out:
#           one  two  three  four
# Ohio        0    0      0     0
# Colorado    0    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
data.loc['Utah']
# Out:
# one       8
# two       9
# three    10
# four     11
# Name: Utah, dtype: int32

# %%
data.loc[['Ohio','Utah'], ['two', 'four']]
# Out:
#       two  four
# Ohio    0     0
# Utah    9    11

# %%
data.loc['Utah', ['one', 'three']]
# Out:
# one       8
# three    10
# Name: Utah, dtype: int32

# %%
data
# Out:
#           one  two  three  four
# Ohio        0    0      0     0
# Colorado    0    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
data.iloc[1:, :2]
# Out:
#           one  two
# Colorado    0    5
# Utah        8    9
# New York   12   13

# %%
data.iloc[[1, 3], [1, 2]]
# Out:
#           two  three
# Colorado    5      6
# New York   13     14

# %% [markdown]
# Both indexing functions work with slices in addition to single labels or lists of labels

# %%
data.loc[:'Utah', 'three']
# Out:
# Ohio         0
# Colorado     6
# Utah        10
# Name: three, dtype: int32

# %%
data.iloc[:, :2][data.three > 5]
# Out:
#           one  two
# Colorado    0    5
# Utah        8    9
# New York   12   13

# %%
data.loc[data['three'] >= 2, ['one', 'three']]
# Out:
#           one  three
# Colorado    0      6
# Utah        8     10
# New York   12     14

# %% [markdown]
# ![Index](Assets/index_operations.png)

# %%
ser = pd.Series(np.arange(3.), index=['a', 'b', 'c'])
ser[-1]
# Out:
# C:\Users\ahamm\AppData\Local\Temp\ipykernel_14864\623005896.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ser[-1]
# 2.0

# %%
ser.iloc[-1]
# Out:
# 2.0

# %%
data
# Out:
#           one  two  three  four
# Ohio        0    0      0     0
# Colorado    0    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
data.loc[:, 'one'] = 1
data
# Out:
#           one  two  three  four
# Ohio        1    0      0     0
# Colorado    1    5      6     7
# Utah        1    9     10    11
# New York    1   13     14    15

# %%
data.iloc[2] = 5
data
# Out:
#           one  two  three  four
# Ohio        1    0      0     0
# Colorado    1    5      6     7
# Utah        5    5      5     5
# New York    1   13     14    15

# %%
data.loc[data.three == 5, 'three'] = 6
data
# Out:
#           one  two  three  four
# Ohio        1    0      0     0
# Colorado    1    5      6     7
# Utah        5    5      6     5
# New York    1   13     14    15

# %% [markdown]
# ## Arithmetic and Data Alignment

# %%
s1 = pd.Series([7.3, -2.5, 3.4, 1.5], index=["a", "c", "d", "e"])

# %%
s2 = pd.Series([-2.1, 3.6, -1.5, 4, 3.1],            
index=["a", "c", "e", "f", "g"])

# %%
s1
# Out:
# a    7.3
# c   -2.5
# d    3.4
# e    1.5
# dtype: float64

# %%
s2
# Out:
# a   -2.1
# c    3.6
# e   -1.5
# f    4.0
# g    3.1
# dtype: float64

# %%
s1+s2
# Out:
# a    5.2
# c    1.1
# d    NaN
# e    0.0
# f    NaN
# g    NaN
# dtype: float64

# %%
df1 = pd.DataFrame(np.arange(9.).reshape((3, 3)), columns=list("bcd"),                  
index=["Ohio", "Texas", "Colorado"])
df2 = pd.DataFrame(np.arange(12.).reshape((4, 3)), columns=list("bde"),                  
index=["Utah", "Ohio", "Texas", "Oregon"])
print(df1)
print(df2)
print(df1+df2)
# Out:
#             b    c    d
# Ohio      0.0  1.0  2.0
# Texas     3.0  4.0  5.0
# Colorado  6.0  7.0  8.0
#           b     d     e
# Utah    0.0   1.0   2.0
# Ohio    3.0   4.0   5.0
# Texas   6.0   7.0   8.0
# Oregon  9.0  10.0  11.0
#             b   c     d   e
# Colorado  NaN NaN   NaN NaN
# Ohio      3.0 NaN   6.0 NaN
# Oregon    NaN NaN   NaN NaN
# Texas     9.0 NaN  12.0 NaN
# Utah      NaN NaN   NaN NaN

# %% [markdown]
#  Arithmetic methods with fill values

# %%
df1 = pd.DataFrame(np.arange(12.).reshape((3, 4)),
                  columns = list('abcd'))
df2 = pd.DataFrame(np.arange(20,).reshape((4, 5)),
                  columns = list('abcde'))
print(df1)
print(df2)
# Out:
#      a    b     c     d
# 0  0.0  1.0   2.0   3.0
# 1  4.0  5.0   6.0   7.0
# 2  8.0  9.0  10.0  11.0
#     a   b   c   d   e
# 0   0   1   2   3   4
# 1   5   6   7   8   9
# 2  10  11  12  13  14
# 3  15  16  17  18  19

# %%
df2.loc[1, 'b'] = np.nan
df2
# Out:
#     a     b   c   d   e
# 0   0   1.0   2   3   4
# 1   5   NaN   7   8   9
# 2  10  11.0  12  13  14
# 3  15  16.0  17  18  19

# %%
df1 + df2
# Out:
#       a     b     c     d   e
# 0   0.0   2.0   4.0   6.0 NaN
# 1   9.0   NaN  13.0  15.0 NaN
# 2  18.0  20.0  22.0  24.0 NaN
# 3   NaN   NaN   NaN   NaN NaN

# %% [markdown]
#  Using the add method on df1, I pass df2 and an argument to fill_value, which
#  substitutes the passed value for any missing values in the operation:

# %%
df1.add(df2, fill_value=0)
# Out:
#       a     b     c     d     e
# 0   0.0   2.0   4.0   6.0   4.0
# 1   9.0   5.0  13.0  15.0   9.0
# 2  18.0  20.0  22.0  24.0  14.0
# 3  15.0  16.0  17.0  18.0  19.0

# %%
1 / df2
# Out:
#           a         b         c         d         e
# 0       inf  1.000000  0.500000  0.333333  0.250000
# 1  0.200000       NaN  0.142857  0.125000  0.111111
# 2  0.100000  0.090909  0.083333  0.076923  0.071429
# 3  0.066667  0.062500  0.058824  0.055556  0.052632

# %% [markdown]
# ![methods](Assets\arithmetic_methods.png)

# %% [markdown]
# ## Function Application and Mapping

# %%
frame = pd.DataFrame(np.random.standard_normal((4, 3)),
                    columns = list('bde'),
                    index = ['Utah', 'Ohio', 'Texas', 'Oregon'])
frame
# Out:
#                b         d         e
# Utah    0.368111  0.547870 -0.877824
# Ohio   -0.940527  0.010221 -1.310529
# Texas  -1.682953  2.022461 -0.856771
# Oregon  0.822821 -1.668332 -0.452923

# %%
np.abs(frame)
# Out:
#                b         d         e
# Utah    0.368111  0.547870  0.877824
# Ohio    0.940527  0.010221  1.310529
# Texas   1.682953  2.022461  0.856771
# Oregon  0.822821  1.668332  0.452923

# %% [markdown]
# Another frequent operation is applying a function on one-dimensional arrays to each
#  column or row. DataFrame’s apply method does exactly this:
#
#  Here the function f, which computes the difference between the maximum and
#  minimum of a Series, is invoked once on each column in frame. The result is a Series
#  having the columns of frame as its index.

# %%
def f1(x):
    return x.max() - x.min()
frame.apply(f1)
# Out:
# b    2.505773
# d    3.690792
# e    0.857607
# dtype: float64

# %%
frame.apply(f1, axis=1)
# Out:
# Utah      1.425695
# Ohio      1.320750
# Texas     3.705413
# Oregon    2.491152
# dtype: float64

# %%
def f2(x):
    return pd.Series([x.min(), x.max()], index=['min', 'max'])
frame.apply(f2)
# Out:
#             b         d         e
# min -1.682953 -1.668332 -1.310529
# max  0.822821  2.022461 -0.452923

# %% [markdown]
# ## Sorting and Ranking

# %%
obj = pd.Series(np.arange(4.), index=list('dbac'))
obj
# Out:
# d    0.0
# b    1.0
# a    2.0
# c    3.0
# dtype: float64

# %%
obj.sort_index()
# Out:
# a    2.0
# b    1.0
# c    3.0
# d    0.0
# dtype: float64

# %%
frame = pd.DataFrame(np.arange(8).reshape((2, 4)),
                    index = ['three', 'one'],
                    columns=list('dabc'))
frame
# Out:
#        d  a  b  c
# three  0  1  2  3
# one    4  5  6  7

# %%
frame.sort_index()
# Out:
#        d  a  b  c
# one    4  5  6  7
# three  0  1  2  3

# %%
frame.sort_index(axis=1)
# Out:
#        a  b  c  d
# three  1  2  3  0
# one    5  6  7  4

# %%
frame.sort_index(axis='columns', ascending=False)
# Out:
#        d  c  b  a
# three  0  3  2  1
# one    4  7  6  5

# %% [markdown]
# To sort a Series by its values, use its sort_values method:

# %%
obj = pd.Series([3, 1, 4, 2])

# %%
obj.sort_values()
# Out:
# 1    1
# 3    2
# 0    3
# 2    4
# dtype: int64

# %%
obj = pd.Series([4, np.nan, 7, np.nan, -3, 2])
obj.sort_values()
# Out:
# 4   -3.0
# 5    2.0
# 0    4.0
# 2    7.0
# 1    NaN
# 3    NaN
# dtype: float64

# %% [markdown]
#  Missing values can be sorted to the start instead by using the na_position option

# %%
obj.sort_values(na_position='first')
# Out:
# 1    NaN
# 3    NaN
# 4   -3.0
# 5    2.0
# 0    4.0
# 2    7.0
# dtype: float64

# %%
frame = pd.DataFrame({"b": [4, 7, -3, 2], "a": [0, 1, 0, 1]})

# %%
frame.sort_values('a')
# Out:
#    b  a
# 0  4  0
# 2 -3  0
# 1  7  1
# 3  2  1

# %%
frame.sort_values(['a', 'b'])
# Out:
#    b  a
# 2 -3  0
# 0  4  0
# 3  2  1
# 1  7  1

# %% [markdown]
# ##  Axis Indexes with Duplicate Labels

# %%
obj = pd.Series(np.arange(5), index=["a", "a", "b", "b", "c"])

# %%
obj
# Out:
# a    0
# a    1
# b    2
# b    3
# c    4
# dtype: int32

# %%
obj.index.is_unique
# Out:
# False

# %%
obj['a']
# Out:
# a    0
# a    1
# dtype: int32

# %% [markdown]
# ## Summarizing and Computing Descriptive Statistics

# %%
df = pd.DataFrame([
    [1.4, np.nan],
    [7.1, -4.5],
    [np.nan, np.nan],
    [0.75,-1.3]
], index=list('abcd'),
columns=['one', 'two'])
df
# Out:
#     one  two
# a  1.40  NaN
# b  7.10 -4.5
# c   NaN  NaN
# d  0.75 -1.3

# %%
df.sum()
# Out:
# one    9.25
# two   -5.80
# dtype: float64

# %%
df.sum(axis=0)#or 'indez\x'
# Out:
# one    9.25
# two   -5.80
# dtype: float64

# %%
df.sum(axis=1)# or 'columns'
# Out:
# a    1.40
# b    2.60
# c    0.00
# d   -0.55
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# a    1.400
# b    1.300
# c      NaN
# d   -0.275
# dtype: float64

# %% [markdown]
# ![Reduction](Assets\reduction_methods.png)

# %% [markdown]
# Some methods, like idxmin and idxmax, return indirect statistics, like the index value
#  where the minimum or maximum values are attained:

# %%
df.idxmax()
# Out:
# one    b
# two    d
# dtype: object

# %%
df.idxmin()
# Out:
# one    d
# two    b
# dtype: object

# %%
df.cumsum()
# Out:
#     one  two
# a  1.40  NaN
# b  8.50 -4.5
# c   NaN  NaN
# d  9.25 -5.8

# %%
df.describe()
# Out:
#             one       two
# count  3.000000  2.000000
# mean   3.083333 -2.900000
# std    3.493685  2.262742
# min    0.750000 -4.500000
# 25%    1.075000 -3.700000
# 50%    1.400000 -2.900000
# 75%    4.250000 -2.100000
# max    7.100000 -1.300000

# %% [markdown]
# ![stats](Assets\stats.png)

# %%
df.count()
# Out:
# one    3
# two    2
# dtype: int64

# %%
df.quantile()
# Out:
# one    1.4
# two   -2.9
# Name: 0.5, dtype: float64

# %% [markdown]
# ## Correlation and Covariance

# %%
df.corr()
# Out:
#      one  two
# one  1.0 -1.0
# two -1.0  1.0

# %% [markdown]
# ## Unique Values, Value Counts, and Membership

# %%
obj = pd.Series(["c", "a", "d", "a", "a", "b", "b", "c", "c"])

# %%
uniques = obj.unique()
uniques
# Out:
# array(['c', 'a', 'd', 'b'], dtype=object)

# %%
uniques = obj.nunique()
uniques
# Out:
# 4

# %%
obj.value_counts()
# Out:
# c    3
# a    3
# b    2
# d    1
# Name: count, dtype: int64

# %%
pd.value_counts(obj.to_numpy(), sort=False)
# Out:
# C:\Users\ahamm\AppData\Local\Temp\ipykernel_14864\164454357.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(obj.to_numpy(), sort=False)
# c    3
# a    3
# d    1
# b    2
# Name: count, dtype: int64

# %%
obj
# Out:
# 0    c
# 1    a
# 2    d
# 3    a
# 4    a
# 5    b
# 6    b
# 7    c
# 8    c
# dtype: object

# %%
mask = obj.isin(['b', 'c'])
mask
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6     True
# 7     True
# 8     True
# dtype: bool

# %%
obj[mask]
# Out:
# 0    c
# 5    b
# 6    b
# 7    c
# 8    c
# dtype: object

# %%
data = pd.DataFrame({"Qu1": [1, 3, 4, 3, 4],                     
                    "Qu2": [2, 3, 1, 2, 3],  
                    "Qu3": [1, 5, 2, 4, 4]})
data
# Out:
#    Qu1  Qu2  Qu3
# 0    1    2    1
# 1    3    3    5
# 2    4    1    2
# 3    3    2    4
# 4    4    3    4

# %%
data['Qu1'].value_counts().sort_index()
# Out:
# Qu1
# 1    1
# 3    2
# 4    2
# Name: count, dtype: int64
